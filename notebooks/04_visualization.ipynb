# %% [markdown]
# # 04 Visualization
#
# Generate and save the standard charts into the `images/` folder.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / 'scripts').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 120)

from IPython.display import Image, display

from scripts.analysis import load_clean_data
from scripts.visualization import save_figures

df = load_clean_data()
figure_paths = save_figures(df)
figure_paths

# %%
for path in figure_paths:
    display(Image(filename=str(path)))

# %% [markdown]
# ## Saved Figures
#
# - `images/top_services.png`
# - `images/category_distribution.png`
# - `images/breach_year_distribution.png`
# - `images/top_domains.png`
