# %% [markdown]
# # 01 Data Understanding
#
# Inspect the raw breach dataset, its structure, and basic quality signals.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / 'scripts').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 120)

from scripts.cleaning import load_data

df = load_data()
df.head()

# %%
df.tail()

# %%
df.sample(5, random_state=42)

# %%
print('Shape:', df.shape)
print('Columns:', list(df.columns))
print('Dtypes:')
print(df.dtypes)

# %%
df.info()

# %%
df.describe(include="all").transpose()

# %%
missing_values = df.isna().sum().sort_values(ascending=False)
duplicate_rows = df.duplicated().sum()
unique_values = df.nunique(dropna=False).sort_values(ascending=False)

print('Missing values per column:')
print(missing_values)
print('Duplicate rows:', duplicate_rows)
print('Unique values per column:')
print(unique_values)

# %% [markdown]
# ## Summary
#
# The raw CSV contains **777** rows. Service names are unique across the file, and the only notable gap is the `Domain` field, which is missing for **38** records.
