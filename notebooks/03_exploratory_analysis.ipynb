# %% [markdown]
# # 03 Exploratory Analysis
#
# Explore breach scale, common data classes, repeated domains, and naming patterns.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / 'scripts').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 120)

from scripts.analysis import category_distribution, domain_frequency, load_clean_data, naming_patterns, service_frequency, summary_statistics, top_services, year_distribution

df = load_clean_data()

# %%
summary_statistics(df)

# %%
service_frequency(df, 10)

# %%
top_services(df, 10, sort_by="pwncount")

# %%
category_distribution(df, 15)

# %%
domain_frequency(df, 10)

# %%
year_distribution(df)

# %%
naming_patterns(df)

# %% [markdown]
# ## Exploration Summary
#
# - Every service name appears once in the file, so `service_frequency` is flat by design.
# - Repeated domains are the better signal for overlap in this dataset.
# - `Email addresses`, `Passwords`, and `Usernames` are the most common exposed data classes.
# - Breach volume concentrates in **2016**.
